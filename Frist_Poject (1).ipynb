# %% [markdown]
# # First Project Due on 10 October 2023

# %% [markdown]
# # Please create a folder called First_Project
#    * ## Download the 2019 Survey from in this link [Stack Overflow](https://insights.stackoverflow.com/survey) and save them in the First_Project Folder
#   * ## Download the Jupyter Notebook and drag it and put it in the First_project
#   * ## Create a GitHub Resository called First_Project
#   * ## Each group must agree to use one GitHub account and add the rest of the group
#   * ## Invite me (doumbiassa@gmail.com) to the GitHub account that your group agreed to use
#   * ## Each member of the group must push at leat three times
#   * ## Each group will will sumbit 1(one) Jupyter notebook
#   * # Leave at least one blank cell between my outputs and your code
#   * ## Each group will prepare and present a 5 to 10 mins power point presentation
#   * ## Each member of the group should present part()_ of the presentation and should be able to answer question about the project
#   * # Push the final version to the designated GitHub repository
#   * # This project is due on 10 October 2023

# %%
# Import pandas library

# %%
import pandas as pd

# %%
# Use pandas to convert the "survey_results_public.csv" to a pandas dataframe and call it df

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
# Print the first five rows of the df
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
#pd.set_option("display.max_row", None)

# %%
pd.set_option("display.max_row", 85)

# %%
# Check the types of social media the respondent used
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
# Print the dimension of the daframe
df.shape
# Out:
# (88883, 85)

# %%
# print the info of df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
# use the set_option to set the maximum number of rows and columns to be 85

# %%
pd.set_option("display.max_row", 85)

# %%
# Check the head of df
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# Transform the "survery_results_schema.csv" into a pandas dataframe and check the first five rows of 
# the dataframe and call it schema_df
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
# Reset the index to Column

# %%
# Your code here
schema_df = schema_df.reset_index(drop=True)

# %%
# Print the entire schema_df
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
# Sort the index of schema_df

# %%
# Use the  new index of Schema_df and the loc method to check the meaning of "SOJobs"
schema_df.sort_index(axis = 0)
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
# Use the  new index of Schema_df and the loc method to check the meaning of "MgrIdiot"
schema_df.loc['SOJobs']['MgrIdiot']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Use the  new index of Schema_df and the loc method to check the meaning of "MgrIdiot"
# ----> 2 schema_df.loc['SOJobs']['MgrIdiot']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
# ...

# %%
# Statistical information about the dataframe df
df.describe().T
# Out:
#                  count          mean           std  min      25%      50%  \
# Respondent     88883.0  4.444200e+04  2.565846e+04  1.0  22221.5  44442.0
# CompTotal      55945.0  5.519014e+11  7.331926e+13  0.0  20000.0  62000.0
# ConvertedComp  55823.0  1.271107e+05  2.841523e+05  0.0  25777.5  57287.0
# WorkWeekHrs    64503.0  4.212720e+01  3.728761e+01  1.0     40.0     40.0
# CodeRevHrs     49790.0  5.084308e+00  5.513931e+00  0.0      2.0      4.0
# Age            79210.0  3.033670e+01  9.178390e+00  1.0     24.0     29.0
#
#                      75%           max
# Respondent      66662.50  8.888300e+04
# CompTotal      120000.00  1.000000e+16
# ConvertedComp  100000.00  2.000000e+06
# WorkWeekHrs        44.75  4.850000e+03
# CodeRevHrs          6.00  9.900000e+01
# Age                35.00  9.900000e+01

# %%
# How many people who code as a hobby
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
# Check the first Respondent in the df, using loc method
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
# Use loc method to check the persons in row 2171 and row 8800 code for hobby
df.loc[[2171, 8800]]
# Out:
#       Respondent                      MainBranch Hobbyist  \
# 2171        2179  I am a developer by profession       No
# 8800        8838  I am a developer by profession      Yes
#
#                      OpenSourcer  \
# 2171                       Never
# 8800  Once a month or more often
#
#                                              OpenSource          Employment  \
# 2171  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 8800  The quality of OSS and closed source software ...  Employed full-time
#
#                  Country Student                                      EdLevel  \
# 2171       United States     NaN     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8800  Russian Federation      No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                          UndergradMajor  ...  \
# 2171  Computer science, computer engineering, or sof...  ...
# 8800                          Mathematics or statistics  ...
#
# ...

# %%
df.loc[[2171, 8800]]['Hobbyist']
# Out:
# 2171     No
# 8800    Yes
# Name: Hobbyist, dtype: object

# %%
# Use loc and slicing methods to check the persons in row 8771 and row 8802 code for hobby

# %%
df.loc[8771: 8802]['Hobbyist']
# Out:
# 8771    Yes
# 8772     No
# 8773     No
# 8774    Yes
# 8775    Yes
# 8776    Yes
# 8777     No
# 8778    Yes
# 8779    Yes
# 8780    Yes
# 8781    Yes
# 8782    Yes
# 8783     No
# 8784    Yes
# 8785     No
# 8786    Yes
# 8787    Yes
# 8788    Yes
# 8789     No
# 8790     No
# 8791    Yes
# 8792    Yes
# 8793    Yes
# 8794    Yes
# 8795    Yes
# 8796    Yes
# 8797    Yes
# 8798    Yes
# 8799     No
# 8800    Yes
# 8801    Yes
# 8802    Yes
# Name: Hobbyist, dtype: object

# %%
# Use loc method to print the following
df.loc[8880: 8882]

# %%
# Reset the index column to Respondent
df = df.set_index('Respondent')

# %%
# Now check the first five rows to make sure that the change was successful

# %%
df.head(5)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
# Filer 
high_salary = (df["ConvertedComp"]>7000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith','ConvertedComp']].sort_values('ConvertedComp', ascending=False).head(100)
# Out:
#              Country                                 LanguageWorkedWith  \
# 38807  United States                     C;C++;JavaScript;Python;R;Rust
# 44241  United States                                         Ruby;Swift
# 41741  United States   HTML/CSS;JavaScript;Objective-C;Python;SQL;Swift
# 13737  United States  HTML/CSS;Java;JavaScript;SQL;TypeScript;Other(s):
# 63558  United States  Bash/Shell/PowerShell;C#;Go;HTML/CSS;JavaScrip...
# ...              ...                                                ...
# 42027  United States            HTML/CSS;Java;JavaScript;SQL;TypeScript
# 71733  United States  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 44271  United States       Bash/Shell/PowerShell;Java;Python;Ruby;Scala
# 15609  United States                                  C#;JavaScript;SQL
# 47712  United States                                    Java;JavaScript
#
#        ConvertedComp
# 38807      2000000.0
# 44241      2000000.0
# 41741      2000000.0
# ...

# %%
# Create a filter filt wich is the Series that contains the Respondent Worked With Python Language
# Hint (use the .str method)

# %%
df[df['LanguageWorkedWith'].str.contains('Python', na=False)]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 1               2  I am a student who is learning to code       No
# 3               4          I am a developer by profession       No
# 4               5          I am a developer by profession      Yes
# 7               8             I code primarily as a hobby      Yes
# ...           ...                                     ...      ...
# 88854       84539                                     NaN      Yes
# 88860       85738                                     NaN      Yes
# 88865       86566                                     NaN      Yes
# 88872       87739                                     NaN      Yes
# 88876       88212                                     NaN       No
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
# Print this

# %%
# Change the name of the column "ConvertedComp" to "Salary_in_USD". Make sure this change is permenent

# %%
df.rename(columns = {'ConvertedComp':'Salary_in_USD'},inplace = True)
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'Salary_in_USD', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.head(3)

# %%
# use map() method to assign Yes to True and No to False in the 'Hobbyist' columns
df['Hobbyist'].map({'Yes':'True', 'No':'False'})
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobbyist, Length: 88883, dtype: object

# %%
# Print the head to see the change

# %%
df.head()

# %%
# How many people code for Hobby?
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
# Sort the values of df by "Country"

# %%
df = df.sort_values(by=['Country'], ascending=True)

# %%
df

# %%
# Check the last five rows

# %%
df.tail

# %%
# How many people from the United States, India, Germany, United Kingdom and Canada responded to the Survery?

# %%
df['Country'].value_counts()[['United States','India','Germany','United Kingdom','Canada']]
# Out:
# United States     20949
# India              9061
# Germany            5866
# United Kingdom     5737
# Canada             3395
# Name: Country, dtype: int64

# %%
# Create a groupby object the countries by Groups; That is grouging all US respondents together, 
#all Uk respondents together....etc.. Call it group_of_countries

# %%
df.groupby(['Country'])["Salary_in_USD"].sum()
# Out:
# Country
# Afghanistan                             1223440.0
# Albania                                 1091685.0
# Algeria                                 1466810.0
# Andorra                                  321862.0
# Angola                                     7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...     627010.0
# Viet Nam                                1499309.0
# Yemen                                    101455.0
# Zambia                                    80603.0
# Zimbabwe                                 510700.0
# Name: Salary_in_USD, Length: 179, dtype: float64

# %%
# Use the groupd_of_country to print this salary information

# %%
group_of_countries = df.groupby(['Country'])

# %%
# Use a for loop through the list ['Nepal', 'Mali', 'United States','United Kingdom','Canada','France']
# and use the printing style to print this

# %%
for country in ['Nepal', 'Mali', 'United States','United Kingdom','Canada','France']:
  print(f"{country}'s top 10 Social Media")
  print(df['Country'].value_counts()[country])
  print('*' * 50)
# Out:
# Nepal's top 10 Social Media
# 237
# **************************************************
# Mali's top 10 Social Media
# 3
# **************************************************
# United States's top 10 Social Media
# 20949
# **************************************************
# United Kingdom's top 10 Social Media
# 5737
# **************************************************
# Canada's top 10 Social Media
# 3395
# **************************************************
# France's top 10 Social Media
# 2391
# **************************************************

# %%
# Do the same thing to print this

# %%
for country in ['Nepal', 'Mali', 'United States','United Kingdom','Canada','France']:
  print(f"{country}'s top 10 Social Media")
  print(df[df['Country']==country]['SocialMedia'].value_counts().nlargest(5))
  print('*' * 50)

# %%
# Do the same thing to print this

# %%
print(df.groupby('Country').get_group(country).agg({'Salary_in_USD': ['mean', 'min', 'max']}))
  print('*' * 50)

# %%
df['YearsCodePro'].value_counts()
# Out:
# 2                     7959
# 3                     7793
# 5                     6416
# 4                     6306
# 6                     4518
# 1                     4449
# 10                    4367
# Less than 1 year      3997
# 7                     3662
# 8                     3449
# 12                    2231
# 15                    2128
# 20                    2061
# 9                     1979
# 11                    1663
# 13                    1376
# 18                    1170
# 14                    1143
# 16                     781
# 19                     772
# 25                     732
# 22                     693
# 17                     632
# 30                     551
# 21                     549
# 23                     454
# 24                     340
# 35                     227
# 28                     223
# 27                     202
# 26                     201
# 32                     176
# 33                     136
# 40                     128
# ...
